# %% [markdown]
# ## Level 2 Task 2(cusine combination)

# %%
 import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
from collections import Counter

# %%
dataset=pd.read_csv(r"C:\Users\User\Downloads\Dataset.csv")

# %%
dataset
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
def identify_common_cuisine_combinations(dataset_path):
    cuisine_combinations=dataset['Cuisines'].str.split('.').explode()
    cuisine_combinations_count=cuisine_combinations.value_counts()
    return cuisine_combinations_count
dataset_path='restaurants.csv'
common_cuisine_combinations= identify_common_cuisine_combinations(dataset_path)
print("most common combinations of Cuisines:")
print(common_cuisine_combinations.head(10))
# Out:
# most common combinations of Cuisines:
# North Indian                      936
# North Indian, Chinese             511
# Chinese                           354
# Fast Food                         354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Name: Cuisines, dtype: int64

# %%
def analyze_cuisine_combinations_and_ratings(dataset_path):
    dataset['cuisine_combination']=dataset['Cuisines'].str.split(',')
    dataset_exploded=dataset.explode('cuisine_combination')
    average_ratings_by_combination=dataset_exploded.groupby('cuisine_combination')['Aggregate rating'].mean()
    sorted_rating=average_ratings_by_combination.sort_values(ascending=False)
    plt.figure(figsize=(7,9))
    sorted_rating.head(10).plot(kind='bar',color='skyblue')
    plt.xlable('Cuisine Combination')
    plt.ylable('Average Rating')
    plt.title('top 10 Cuisines Combinations with highest Average Ratings') 
    plt.xticks(rotation=45,ha='right')
    plt.grid(True)
    plt.tight_layout()
    plt.show()
    return sorting_ratings
dataset_path='restaurants.csv'
sorted_ratings=analyze_cuisine_combinations_and_ratings(dataset_path)
print("Average ratings for top 10 cuisine combinations:")
print(sorted_ratings.head(10))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 17
#      15     return sorting_ratings
#      16 dataset_path='restaurants.csv'
# ---> 17 sorted_ratings=analyze_cuisine_combinations_and_ratings(dataset_path)
#      18 print("Average ratings for top 10 cuisine combinations:")
#      19 print(sorted_ratings.head(10))
#
# Cell In[39], line 8, in analyze_cuisine_combinations_and_ratings(dataset_path)
#       6 plt.figure(figsize=(7,9))
#       7 sorted_rating.head(10).plot(kind='bar',color='skyblue')
# ----> 8 plt.xlable('Cuisine Combination')
#       9 plt.ylable('Average Rating')
#      10 plt.title('top 10 Cuisines Combinations with highest Average Ratings')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'
